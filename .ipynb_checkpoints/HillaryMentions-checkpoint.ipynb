# %%
from sqlalchemy import *
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

db = create_engine('mysql://root:nycdsa1!@nycdsa.cqtxbycscfmw.us-west-2.rds.amazonaws.com:3306/hillary')

# nice when it's simple.
sql = "SELECT * FROM Emails;"
Emails = pd.read_sql(sql, db)

# %%
# indices of which emails contain a benghazi mention
beng = Emails['ExtractedBodyText'].str.contains('(.*benghazi.*)', case = False)
obama = Emails['ExtractedBodyText'].str.contains('(.*obama.*)', case = False)
hillary = Emails['ExtractedBodyText'].str.contains('(.*hillary.*)', case = False)
libya = Emails['ExtractedBodyText'].str.contains('(.*libya.*)', case = False)
qaddafi = Emails['ExtractedBodyText'].str.contains('(.*qaddafi.*)', case = False)

# %%
print Emails[beng].ExtractedBodyText.size
print Emails[obama].ExtractedBodyText.size
print Emails[hillary].ExtractedBodyText.size
print Emails[qaddafi].ExtractedBodyText.size
print Emails[libya].ExtractedBodyText.size
# Out:
# 66
# 210
# 237
# 9
# 70

# %%
froms = pd.unique(Emails.ExtractedFrom)

print np.sort(froms)

# print Emails[Emails['ExtractedFrom']
# Out:
# ['' "' Mills, Cheryl D <MillsCD@state.gov>"
#  '* Abedin, Huma <AbedinH@state.gov>' '- Abedin, Huma <AbedinH@state.gov>'
#  '. H <hrod17@clintonemail.com >'
#  '. Sullivan, Jacobi <Sullivanil@state.gov>'
#  '0 Mills, Cheryl D <MillsCD@state.gov>' "1-1'<hrod17@clintonemail.com>"
#  'Abeclin, Huma <AbedinH@state.gov>' 'Abed in, Hu ma <AbedinH@state.gov>'
#  'Abed in, Huma <AbedinH@state.gov>' 'Abed in, Huma <AbedinH@state.goy>'
#  'Abed in, Huma <AbedinH\xa9state.gov>' 'Abedin, Hu ma <AbedinH@state.gov>'
#  'Abedin, Huma <AIDedinH@state.gov>' 'Abedin, Huma <AbedinH@state.goV>'
#  'Abedin, Huma <AbedinH@state.gov>' 'Abedin, Huma <AbedinH@state.gov> .'
#  'Abedin, Huma <AbedinH@state.goy>' 'Abedin, Huma <AbedinH\xa9state,gov>'
#  'Abedin, Huma <AbedinH\xa9state.gov>'
#  'Abedin, Huma <AbedinH\xa9state.goy>' 'Abedin, Huma eAbedinH@state.gov>'
#  'Abedin, Hume <AbeclinH@stategov\x9b' 'Abedin, Hume <AbedinH state.gov>'
# ...

# %%
print Emails[Emails['ExtractedFrom'].str.contains('(^H[\s.]{1})', case = False)].shape[0]

EmailsH = Emails[Emails['ExtractedFrom'].str.contains('(^H[\s.]{1})', case = False)]
# Out:
# 1730

# %%
print EmailsH['ExtractedBodyText'][EmailsH['ExtractedBodyText'].str.contains('(.*benghazi.*)', case = False)].shape[0]
print Emails['ExtractedBodyText'][Emails['ExtractedBodyText'].str.contains('(.*benghazi.*)', case = False)].shape[0]
# Out:
# 5
# 66
