# %%
from sqlalchemy import *
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

db = create_engine('mysql://root:nycdsa1!@nycdsa.cqtxbycscfmw.us-west-2.rds.amazonaws.com:3306/hillary')

# nice when it's simple.
sql = "SELECT * FROM Emails;"
Emails = pd.read_sql(sql, db)

# %%
# indices of which emails contain a benghazi mention
beng = Emails['ExtractedBodyText'].str.contains('(.*benghazi.*)', case = False)
obama = Emails['ExtractedBodyText'].str.contains('(.*obama.*)', case = False)
hillary = Emails['ExtractedBodyText'].str.contains('(.*hillary.*)', case = False)
libya = Emails['ExtractedBodyText'].str.contains('(.*libya.*)', case = False)
qaddafi = Emails['ExtractedBodyText'].str.contains('(.*qaddafi.*)', case = False)

# %%
# how many emails have mentions of the above categories?
print Emails[beng].ExtractedBodyText.size
print Emails[obama].ExtractedBodyText.size
print Emails[hillary].ExtractedBodyText.size
print Emails[qaddafi].ExtractedBodyText.size
print Emails[libya].ExtractedBodyText.size
# Out:
# 66
# 210
# 237
# 9
# 70

# %%
froms = pd.unique(Emails.MetadataFrom)

print np.sort(froms)
# Out:
# ['' '111th Congress' 'AF/PDPA:Scott, Marianne'
#  'AGNA USEMB Kabul Afghanistan' 'AP' 'Abedin, Huma' 'AbedinH@state.gov'
#  'Abein, Huma' 'Abendin, Huma' 'Adedin, Huma' 'Adler, Caroline E'
#  'Albright, M K' 'Albright, Madeleine' 'Alec'
#  'American Beverage Association' 'Axelrod, David M'
#  'BAM@Mikulski.senate.gov' 'BLAIR CHERIE' 'Baer, Daniel' 'Baer, Daniel B'
#  'Baer, Daniel D' 'BaldersonKM@state.gov' 'Balderston, Kris M'
#  'Balderstone, Kris M' 'Baucus, Max' 'Beale, Courtney A Karamer'
#  'Beale, Courtney A Kramer' 'Berger, Samuel' 'Berger, Samuel R'
#  'Blair Cherie' 'Blair, Cherie' 'Blake, Robert O' 'Blumenthal, Sidney'
#  'Brian, Danielle' 'Brimmer, Esther D' 'Brock, David' 'Brown, Lee R'
#  'Burns, William J' 'Button, Case' 'Butzgy, Christopher H'
#  'C:Mills, Cheryl' 'CHERIE BLAIR' 'Calivis, Maria' 'Campbell, Kurt M'
#  'Campbell, Piper' 'Capricia Marshall' 'Carson, Johnnie' 'Chelsea'
#  'Cheryl Mills' 'Cheryl.mills' 'Chollet, Derek H' 'Clinton Hillary R'
# ...

# %%
# main kinds of emails
# MetadataFrom has better data.
print Emails.groupby('ExtractedFrom', as_index = False) \
        .agg('count') \
        .sort_values(axis = 0, by = 'Id', ascending = False) \
        [['ExtractedFrom','Id']] \
        .head()

print 

# different between extracted and metadata
print Emails.groupby('MetadataFrom', as_index = False) \
        .agg('count') \
        .sort_values(axis = 0, by = 'Id', ascending = False) \
        [['MetadataFrom','Id']] \
        .head()
        
print

# only 157 missing emails here! what to do?
print Emails[Emails.MetadataFrom == ''].groupby('MetadataFrom', as_index = False) \
        .agg('count') \
        .sort_values(axis = 0, by = 'Id', ascending = False) \
        [['MetadataFrom','Id']] \
        .head()
# Out:
#                                 ExtractedFrom    Id
# 123               H <hrod17@clintonemail.com>  1415
# 0                                              1253
# 16           Abedin, Huma <AbedinH@state.gov>  1034
# 256       Mills, Cheryl D <MillsCD@state.gov>   890
# 389  Sullivan, Jacob J <SullivanJJ@state.gov>   425
#
#           MetadataFrom    Id
# 90                   H  1906
# 5         Abedin, Huma  1380
# 156    Mills, Cheryl D  1146
# 238  Sullivan, Jacob J   750
# 286           sbwhoeop   316
#
#   MetadataFrom   Id
# 0               157

# %%
# iter through "crap" data, what's here that we maybe can work with?
x = 0
for item in Emails.ExtractedBodyText[Emails.MetadataFrom == ''].head(50):
    if x == 5: # this is just to control looping
        break
    print item, '\n'
    x += 1
# Out:
# B6
# Thursday, March 3, 2011 9:45 PM
# H: Latest How Syria is aiding Qaddafi and more... Sid
# hrc memo syria aiding libya 030311.docx; hrc memo syria aiding libya 030311.docx
# March 3, 2011
# For: Hillary
#
# B6
# Wednesday, September 12, 2012 6:16 PM
# Fwd: more on libya
# Libya 37 sept 12 12.docx
# Sending direct. Just in.
# Sent from my Verizon Wireless 4G LTE DRUID
#
# B6
# Wednesday, September 12, 2012 6:16 PM
# Fwd: more on libya
# Libya 37 sept 12 12.docx
# Sending direct. Just in.
# Sent from my Verizon Wireless 4G LTE DRUID
#
# B6
# Sunday, March 27, 201i 9:05 PM
# H: Lots of new intel; possible Libyan collapse. Sid
# hic memo lots of new Intel; possible imminent collapse 032711.docx; hrc memo lots of
# new intel; possible imminent collapse 032711.docx
# March 27. 2011
# For: Hillary
# From Sid
# Re: Lots of new Intel; Libyan army possibly on verge of collapse
# Latest:
# ...

# %%
# consolidate email "To" field
Emails_cons = Emails.copy()

# this turned out to be mostly unnecesary. just use MetadataFrom, BUT still some cleaning to be done there.
Emails_cons['ExtractedFrom'][Emails_cons['ExtractedFrom'].str.contains('(.*abedin.*)', case = False)] = 'Abedin, Huma <AbedinH@state.gov>'
Emails_cons['ExtractedFrom'][Emails_cons['ExtractedFrom'].str.contains('(.*(hrod17|h <).*)', case = False)] = 'H <hrod17@clintonemail.com>'
Emails_cons['ExtractedFrom'][Emails_cons['ExtractedFrom'].str.contains('(.*(Mills, Cheryl|Mills.{0,2}Cheryl).*)', case = False)] = 'Mills, Cheryl D <MillsCD@state.gov>'
Emails_cons['ExtractedFrom'][Emails_cons['ExtractedFrom'].str.contains('(.*Sullivan, Jacob.*)', case = False)] = 'Sullivan, Jacob J <SullivanJJ@state.gov>'
Emails_cons['ExtractedFrom'][Emails_cons['ExtractedFrom'].str.contains('(.*Valmoro, Lona.*)', case = False)] = 'Valmoro, Lona J <ValmoroU@state.gov>'
Emails_cons['ExtractedFrom'][Emails_cons['ExtractedFrom'].str.contains('(.*Jiloty, Lauren.*)', case = False)] = 'Jiloty, Lauren C <JilotyLC@state.gov>'
# Out:
# ['' 'Abedin, Huma <AbedinH@state.gov>'
#  'Adler, Caroline E <AdlerCE@state.gov>' 'Alec' 'Andy Manatos'
#  'Anne-Marie Slaughter' 'Axelrod, David M.' 'Axelrod, David M. B6' 'B6'
#  'Baer, Daniel B <BaerDB@state.gov>'
#  'Balderston, Kris M <BalderstonKM@state.gov>'
#  'Balderston, Kris M <BalderstonKM\xa9state.gov>' 'Barton, Rick (CSO)'
#  'Beale, Courtney A Kramer <BealeCA@state.gov>' 'Ben Kobren'
#  'Berger, Samuel R.' 'Berger, Samuel R. B6'
#  'Blake, Robert 0 <BlakeR2@state.gov>'
#  'Brimmer, Esther D <BrimmerE@state.gov>'
#  'Bums, William J <BurnsWi@state.gov>' 'Burns Strider' 'Burns Strider B6'
#  'Burns, William J <BurnsW.1@state.gov>'
#  'Burns, William J <BurnsWJ@state.gov>'
#  'Burns, William J <BurnsWi@state.gov>' 'C \x97 Cheryl Mills'
#  'Campbell, Kurt M <CampbelIKM@state.gov>'
#  'Campbell, Kurt M <CampbellKM@state.gov>'
#  'Campbell, Piper <CampbellP@state.gov>' 'Capricia Marshall'
#  'Carson, Johnnie <CarsonJ@state.gov>' 'CdeBaca, Luis' 'Cherie Blair'
# ...

# %%
print np.sort(pd.unique(Emails_cons.MetadataFrom)) # check: abedin, abein, abendin, adedin :(
# Out:
# ['' '111th Congress' 'AF/PDPA:Scott, Marianne'
#  'AGNA USEMB Kabul Afghanistan' 'AP' 'Abedin, Huma' 'AbedinH@state.gov'
#  'Abein, Huma' 'Abendin, Huma' 'Adedin, Huma' 'Adler, Caroline E'
#  'Albright, M K' 'Albright, Madeleine' 'Alec'
#  'American Beverage Association' 'Axelrod, David M'
#  'BAM@Mikulski.senate.gov' 'BLAIR CHERIE' 'Baer, Daniel' 'Baer, Daniel B'
#  'Baer, Daniel D' 'BaldersonKM@state.gov' 'Balderston, Kris M'
#  'Balderstone, Kris M' 'Baucus, Max' 'Beale, Courtney A Karamer'
#  'Beale, Courtney A Kramer' 'Berger, Samuel' 'Berger, Samuel R'
#  'Blair Cherie' 'Blair, Cherie' 'Blake, Robert O' 'Blumenthal, Sidney'
#  'Brian, Danielle' 'Brimmer, Esther D' 'Brock, David' 'Brown, Lee R'
#  'Burns, William J' 'Button, Case' 'Butzgy, Christopher H'
#  'C:Mills, Cheryl' 'CHERIE BLAIR' 'Calivis, Maria' 'Campbell, Kurt M'
#  'Campbell, Piper' 'Capricia Marshall' 'Carson, Johnnie' 'Chelsea'
#  'Cheryl Mills' 'Cheryl.mills' 'Chollet, Derek H' 'Clinton Hillary R'
# ...
